# %%
import pandas as pd

# %%
df = pd.read_csv('Data/apple_products.csv')

# %%
df.head()
# Out:
#                                Product Name  \
# 0         APPLE iPhone 8 Plus (Gold, 64 GB)
# 1  APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2      APPLE iPhone 8 Plus (Silver, 256 GB)
# 3           APPLE iPhone 8 (Silver, 256 GB)
# 4             APPLE iPhone 8 (Gold, 256 GB)
#
#                                          Product URL  Brand  Sale Price  \
# 0  https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1  https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2  https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3  https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# 4  https://www.flipkart.com/apple-iphone-8-gold-2...  Apple       77000
#
#      Mrp  Discount Percentage  Number Of Ratings  Number Of Reviews  \
# 0  49900                    0               3431                356
# 1  84900                    0               3431                356
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of                                 Product Name  \
# 0          APPLE iPhone 8 Plus (Gold, 64 GB)
# 1   APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2       APPLE iPhone 8 Plus (Silver, 256 GB)
# 3            APPLE iPhone 8 (Silver, 256 GB)
# 4              APPLE iPhone 8 (Gold, 256 GB)
# ..                                       ...
# 57            APPLE iPhone SE (Black, 64 GB)
# 58           APPLE iPhone 11 (Purple, 64 GB)
# 59            APPLE iPhone 11 (White, 64 GB)
# 60            APPLE iPhone 11 (Black, 64 GB)
# 61              APPLE iPhone 11 (Red, 64 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 0   https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3   https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# ...

# %%
df
# Out:
#                                 Product Name  \
# 0          APPLE iPhone 8 Plus (Gold, 64 GB)
# 1   APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2       APPLE iPhone 8 Plus (Silver, 256 GB)
# 3            APPLE iPhone 8 (Silver, 256 GB)
# 4              APPLE iPhone 8 (Gold, 256 GB)
# ..                                       ...
# 57            APPLE iPhone SE (Black, 64 GB)
# 58           APPLE iPhone 11 (Purple, 64 GB)
# 59            APPLE iPhone 11 (White, 64 GB)
# 60            APPLE iPhone 11 (Black, 64 GB)
# 61              APPLE iPhone 11 (Red, 64 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 0   https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3   https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# ...

# %%
df.count() #rows
# Out:
# Product Name           62
# Product URL            62
# Brand                  62
# Sale Price             62
# Mrp                    62
# Discount Percentage    62
# Number Of Ratings      62
# Number Of Reviews      62
# Upc                    62
# Star Rating            62
# Ram                    62
# dtype: int64

# %%
df['Mrp'].max()
# Out:
# 149900

# %%
df['Mrp'].min()
# Out:
# 39900

# %%
df[df['Mrp']==df['Mrp'].max()]
# Out:
#                                   Product Name  \
# 24        APPLE iPhone 12 Pro (Silver, 512 GB)
# 41  APPLE iPhone 12 Pro (Pacific Blue, 512 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 24  https://www.flipkart.com/apple-iphone-12-pro-s...  Apple      140900
# 41  https://www.flipkart.com/apple-iphone-12-pro-p...  Apple      140900
#
#        Mrp  Discount Percentage  Number Of Ratings  Number Of Reviews  \
# 24  149900                    6                542                 42
# 41  149900                    6                545                 42
#
#                  Upc  Star Rating   Ram
# 24  MOBFWBYZ5UY6ZBVA          4.5  4 GB
# 41  MOBFWBYZTHSXKMGW          4.5  4 GB

# %%
df[df['Mrp']==df['Mrp'].min()]
# Out:
#                       Product Name  \
# 52  APPLE iPhone SE (White, 64 GB)
# 57  APPLE iPhone SE (Black, 64 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 52  https://www.flipkart.com/apple-iphone-se-white...  Apple       29999
# 57  https://www.flipkart.com/apple-iphone-se-black...  Apple       29999
#
#       Mrp  Discount Percentage  Number Of Ratings  Number Of Reviews  \
# 52  39900                   24              95807               8154
# 57  39900                   24              95909               8161
#
#                  Upc  Star Rating   Ram
# 52  MOBFWQ6BGWDVGF3E          4.5  2 GB
# 57  MOBFWQ6BR3MK7AUG          4.5  4 GB

# %%
df[df['Mrp']<50000]
# Out:
#                                          Product Name  \
# 0                   APPLE iPhone 8 Plus (Gold, 64 GB)
# 5                 APPLE iPhone 8 Plus (Silver, 64 GB)
# 6             APPLE iPhone 8 Plus (Space Grey, 64 GB)
# 10  Apple iPhone XR (Black, 64 GB) (Includes EarPo...
# 52                     APPLE iPhone SE (White, 64 GB)
# 53                    APPLE iPhone SE (Black, 128 GB)
# 54                    APPLE iPhone SE (White, 128 GB)
# 55                      APPLE iPhone SE (Red, 128 GB)
# 57                     APPLE iPhone SE (Black, 64 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 0   https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 5   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       49900
# 6   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       49900
# 10  https://www.flipkart.com/apple-iphone-xr-black...  Apple       39999
# ...

# %%
df[df['Mrp']>100000].count()
# Out:
# Product Name           22
# Product URL            22
# Brand                  22
# Sale Price             22
# Mrp                    22
# Discount Percentage    22
# Number Of Ratings      22
# Number Of Reviews      22
# Upc                    22
# Star Rating            22
# Ram                    22
# dtype: int64

# %% [markdown]
# # Create new column to check name of the model

# %%
df.head()
# Out:
#                                Product Name  \
# 0         APPLE iPhone 8 Plus (Gold, 64 GB)
# 1  APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2      APPLE iPhone 8 Plus (Silver, 256 GB)
# 3           APPLE iPhone 8 (Silver, 256 GB)
# 4             APPLE iPhone 8 (Gold, 256 GB)
#
#                                          Product URL  Brand  Sale Price  \
# 0  https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1  https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2  https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3  https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# 4  https://www.flipkart.com/apple-iphone-8-gold-2...  Apple       77000
#
#      Mrp  Discount Percentage  Number Of Ratings  Number Of Reviews  \
# 0  49900                    0               3431                356
# 1  84900                    0               3431                356
# ...

# %%
type(df['Product Name'])
# Out:
# pandas.core.series.Series

# %%
type(list(df['Product Name']))
# Out:
# list

# %%
list(df['Product Name'])[10][6:15].strip()
# Out:
# 'iPhone XR'

# %%
df['Model Name'] = df['Product Name'].str[6:15]

# %%
df['Model Name']
# Out:
# 0     iPhone 8
# 1     iPhone 8
# 2     iPhone 8
# 3     iPhone 8
# 4     iPhone 8
#         ...
# 57    iPhone SE
# 58    iPhone 11
# 59    iPhone 11
# 60    iPhone 11
# 61    iPhone 11
# Name: Model Name, Length: 62, dtype: object

# %%
df
# Out:
#                                 Product Name  \
# 0          APPLE iPhone 8 Plus (Gold, 64 GB)
# 1   APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2       APPLE iPhone 8 Plus (Silver, 256 GB)
# 3            APPLE iPhone 8 (Silver, 256 GB)
# 4              APPLE iPhone 8 (Gold, 256 GB)
# ..                                       ...
# 57            APPLE iPhone SE (Black, 64 GB)
# 58           APPLE iPhone 11 (Purple, 64 GB)
# 59            APPLE iPhone 11 (White, 64 GB)
# 60            APPLE iPhone 11 (Black, 64 GB)
# 61              APPLE iPhone 11 (Red, 64 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 0   https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3   https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# ...

# %% [markdown]
# Create new column color

# %%
df.head()
# Out:
#                                Product Name  \
# 0         APPLE iPhone 8 Plus (Gold, 64 GB)
# 1  APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2      APPLE iPhone 8 Plus (Silver, 256 GB)
# 3           APPLE iPhone 8 (Silver, 256 GB)
# 4             APPLE iPhone 8 (Gold, 256 GB)
#
#                                          Product URL  Brand  Sale Price  \
# 0  https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1  https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2  https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3  https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# 4  https://www.flipkart.com/apple-iphone-8-gold-2...  Apple       77000
#
#      Mrp  Discount Percentage  Number Of Ratings  Number Of Reviews  \
# 0  49900                    0               3431                356
# 1  84900                    0               3431                356
# ...

# %%
df['Product Name']
# Out:
# 0            APPLE iPhone 8 Plus (Gold, 64 GB)
# 1     APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2         APPLE iPhone 8 Plus (Silver, 256 GB)
# 3              APPLE iPhone 8 (Silver, 256 GB)
# 4                APPLE iPhone 8 (Gold, 256 GB)
#                         ...
# 57              APPLE iPhone SE (Black, 64 GB)
# 58             APPLE iPhone 11 (Purple, 64 GB)
# 59              APPLE iPhone 11 (White, 64 GB)
# 60              APPLE iPhone 11 (Black, 64 GB)
# 61                APPLE iPhone 11 (Red, 64 GB)
# Name: Product Name, Length: 62, dtype: object

# %%
df['Color'] = df['Product Name'].str[19:]

# %%
df['Color']
# Out:
# 0             (Gold, 64 GB)
# 1      (Space Grey, 256 GB)
# 2          (Silver, 256 GB)
# 3              ver, 256 GB)
# 4                d, 256 GB)
#               ...
# 57              ack, 64 GB)
# 58             rple, 64 GB)
# 59              ite, 64 GB)
# 60              ack, 64 GB)
# 61                d, 64 GB)
# Name: Color, Length: 62, dtype: object

# %%
# Sort in descending order on the basis of star ratings
df_sorted = df.sort_values(by=['Star Rating'], ascending=False)

# %%
list(df.sort_values(by=['Star Rating'], ascending=False))[-1]
# Out:
# 'Color'

# %%
df_sorted
# Out:
#                                          Product Name  \
# 20    APPLE iPhone 11 Pro Max (Midnight Green, 64 GB)
# 17        APPLE iPhone 11 Pro Max (Space Grey, 64 GB)
# 16   APPLE iPhone 11 Pro Max (Midnight Green, 256 GB)
# 15              APPLE iPhone 11 Pro Max (Gold, 64 GB)
# 14             APPLE iPhone 11 Pro Max (Gold, 256 GB)
# ..                                                ...
# 45                APPLE iPhone 12 Mini (Black, 64 GB)
# 28                APPLE iPhone 12 Mini (White, 64 GB)
# 23  Apple iPhone SE (White, 256 GB) (Includes EarP...
# 41         APPLE iPhone 12 Pro (Pacific Blue, 512 GB)
# 27             APPLE iPhone 12 Pro (Graphite, 256 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 20  https://www.flipkart.com/apple-iphone-11-pro-m...  Apple      117100
# 17  https://www.flipkart.com/apple-iphone-11-pro-m...  Apple      117100
# 16  https://www.flipkart.com/apple-iphone-11-pro-m...  Apple      131900
# ...

# %%
type(df_sorted)
# Out:
# pandas.core.frame.DataFrame

# %%
df_sorted.iloc[-1]
# Out:
# Product Name                      APPLE iPhone 12 Pro (Graphite, 256 GB)
# Product URL            https://www.flipkart.com/apple-iphone-12-pro-g...
# Brand                                                              Apple
# Sale Price                                                        120900
# Mrp                                                               129900
# Discount Percentage                                                    6
# Number Of Ratings                                                    545
# Number Of Reviews                                                     42
# Upc                                                     MOBFWBYZBA36UB7G
# Star Rating                                                          4.5
# Ram                                                                 6 GB
# Model Name                                                     iPhone 12
# Color                                                 (Graphite, 256 GB)
# ...

# %%
df
# Out:
#                                 Product Name  \
# 0          APPLE iPhone 8 Plus (Gold, 64 GB)
# 1   APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2       APPLE iPhone 8 Plus (Silver, 256 GB)
# 3            APPLE iPhone 8 (Silver, 256 GB)
# 4              APPLE iPhone 8 (Gold, 256 GB)
# ..                                       ...
# 57            APPLE iPhone SE (Black, 64 GB)
# 58           APPLE iPhone 11 (Purple, 64 GB)
# 59            APPLE iPhone 11 (White, 64 GB)
# 60            APPLE iPhone 11 (Black, 64 GB)
# 61              APPLE iPhone 11 (Red, 64 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 0   https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3   https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# ...

# %%
df.sort_values(by=['Sale Price'], ascending=False)
# Out:
#                                         Product Name  \
# 41        APPLE iPhone 12 Pro (Pacific Blue, 512 GB)
# 24              APPLE iPhone 12 Pro (Silver, 512 GB)
# 16  APPLE iPhone 11 Pro Max (Midnight Green, 256 GB)
# 14            APPLE iPhone 11 Pro Max (Gold, 256 GB)
# 31        APPLE iPhone 12 Pro Max (Graphite, 256 GB)
# ..                                               ...
# 54                   APPLE iPhone SE (White, 128 GB)
# 55                     APPLE iPhone SE (Red, 128 GB)
# 53                   APPLE iPhone SE (Black, 128 GB)
# 52                    APPLE iPhone SE (White, 64 GB)
# 57                    APPLE iPhone SE (Black, 64 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 41  https://www.flipkart.com/apple-iphone-12-pro-p...  Apple      140900
# 24  https://www.flipkart.com/apple-iphone-12-pro-s...  Apple      140900
# 16  https://www.flipkart.com/apple-iphone-11-pro-m...  Apple      131900
# ...
