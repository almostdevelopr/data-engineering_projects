# %%
# !pip3 install spotipy
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.9/238.9 kB 4.1 MB/s eta 0:00:005.7 MB/s eta 0:00:01
# ...
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ...

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
client_credentials_manager=SpotifyClientCredentials(client_id='97e7b003e28e4ae8b014112fe70b4b5b',client_secret='a83f08d192564e75834ed8abe429b132')

# %%
sp=spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
top_playlist_global='https://open.spotify.com/playlist/37i9dQZEVXbNG2KDcFcKOF'

# %%
top_playlist_global_uri=top_playlist_global.split('/')[-1]

# %%
top_playlist_global_uri
# Out:
# '37i9dQZEVXbNG2KDcFcKOF'

# %%
data=sp.playlist_tracks(top_playlist_global_uri)
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# File /opt/homebrew/Cellar/jupyterlab/3.3.2/libexec/lib/python3.9/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:3, in raise_from(value, from_value)
#
# ...

# %%
data
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/37i9dQZEVXbNG2KDcFcKOF/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2023-04-14T09:53:58Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_group': 'album',
#      'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5YGY8feqx7naU7z4HrwZM6'},
#        'href': 'https://api.spotify.com/v1/artists/5YGY8feqx7naU7z4HrwZM6',
#        'id': '5YGY8feqx7naU7z4HrwZM6',
#        'name': 'Miley Cyrus',
#        'type': 'artist',
#        'uri': 'spotify:artist:5YGY8feqx7naU7z4HrwZM6'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
# ...

# %%
data['items'][0]
# Out:
# {'added_at': '2023-04-14T09:53:58Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#   'href': 'https://api.spotify.com/v1/users/',
#   'id': '',
#   'type': 'user',
#   'uri': 'spotify:user:'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'album': {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5YGY8feqx7naU7z4HrwZM6'},
#      'href': 'https://api.spotify.com/v1/artists/5YGY8feqx7naU7z4HrwZM6',
#      'id': '5YGY8feqx7naU7z4HrwZM6',
#      'name': 'Miley Cyrus',
#      'type': 'artist',
#      'uri': 'spotify:artist:5YGY8feqx7naU7z4HrwZM6'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
# ...

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'Endless Summer Vacation'

# %%
singer_name=data['items'][0]['track']['album']['artists'][0]['name']

# %%
singer_name
# Out:
# 'Miley Cyrus'

# %%
data['items'][0]['track']['album']['id']
# Out:
# '0HiZ8fNXwJOQcrf5iflrdz'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'Endless Summer Vacation'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 13

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2023-03-10'

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/0HiZ8fNXwJOQcrf5iflrdz'

# %%
album_list=[]
for row in data['items']:
    album_id=row['track']['album']['id']
    album_name=row['track']['album']['name']
    album_release_date=row['track']['album']['release_date']
    album_total_tracks=row['track']['album']['total_tracks']
    album_url=row['track']['album']['external_urls']['spotify']
    album_elements={'album_id':album_id,'album_name':album_name,'album_release_date':album_release_date,
                   'album_total_tracks':album_total_tracks,'album_url':album_url}
    album_list.append(album_elements)

# %%
album_list
# Out:
# [{'album_id': '0HiZ8fNXwJOQcrf5iflrdz',
#   'album_name': 'Endless Summer Vacation',
#   'album_release_date': '2023-03-10',
#   'album_total_tracks': 13,
#   'album_url': 'https://open.spotify.com/album/0HiZ8fNXwJOQcrf5iflrdz'},
#  {'album_id': '3Mm1P5CEEAiuJqBclr2EyU',
#   'album_name': 'Ella Baila Sola',
#   'album_release_date': '2023-03-16',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/3Mm1P5CEEAiuJqBclr2EyU'},
#  {'album_id': '1nrVofqDRs7cpWXJ49qTnP',
#   'album_name': 'SOS',
#   'album_release_date': '2022-12-08',
#   'album_total_tracks': 23,
#   'album_url': 'https://open.spotify.com/album/1nrVofqDRs7cpWXJ49qTnP'},
#  {'album_id': '4kS7bSuU0Jm9LYMosFU2x5',
#   'album_name': 'MAÑANA SERÁ BONITO',
#   'album_release_date': '2023-02-24',
#   'album_total_tracks': 17,
#   'album_url': 'https://open.spotify.com/album/4kS7bSuU0Jm9LYMosFU2x5'},
#  {'album_id': '6aBVGuOUEuX18rHxyDWbti',
#   'album_name': 'La Bebe (Remix)',
# ...

# %%
artist_list = []
for row in data['items']:
    for key, value in row.items():
        if key == "track":
            for artist in value['artists']:
                artist_dict = {'artist_id':artist['id'], 'artist_name':artist['name'], 'external_url': artist['href']}
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '5YGY8feqx7naU7z4HrwZM6',
#   'artist_name': 'Miley Cyrus',
#   'external_url': 'https://api.spotify.com/v1/artists/5YGY8feqx7naU7z4HrwZM6'},
#  {'artist_id': '0XeEobZplHxzM9QzFQWLiR',
#   'artist_name': 'Eslabon Armado',
#   'external_url': 'https://api.spotify.com/v1/artists/0XeEobZplHxzM9QzFQWLiR'},
#  {'artist_id': '12GqGscKJx3aE4t07u7eVZ',
#   'artist_name': 'Peso Pluma',
#   'external_url': 'https://api.spotify.com/v1/artists/12GqGscKJx3aE4t07u7eVZ'},
#  {'artist_id': '7tYKF4w9nC0nq9CsPZTHyP',
#   'artist_name': 'SZA',
#   'external_url': 'https://api.spotify.com/v1/artists/7tYKF4w9nC0nq9CsPZTHyP'},
#  {'artist_id': '790FomKkXshlbRYZFtlgla',
#   'artist_name': 'KAROL G',
#   'external_url': 'https://api.spotify.com/v1/artists/790FomKkXshlbRYZFtlgla'},
#  {'artist_id': '0EmeFodog0BfCgMzAIvKQp',
#   'artist_name': 'Shakira',
#   'external_url': 'https://api.spotify.com/v1/artists/0EmeFodog0BfCgMzAIvKQp'},
#  {'artist_id': '1NNRWkhwmcXRimFYSBpB1y',
# ...

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id,'song_name':song_name,'duration_ms':song_duration,'url':song_url,
                    'popularity':song_popularity,'song_added':song_added,'album_id':album_id,
                    'artist_id':artist_id
                   }
    song_list.append(song_element)

# %%
import pandas as pd

# %%
album_df=pd.DataFrame.from_dict(album_list)

# %%
album_df
# Out:
#                   album_id                                      album_name  \
# 0   0HiZ8fNXwJOQcrf5iflrdz                         Endless Summer Vacation
# 1   3Mm1P5CEEAiuJqBclr2EyU                                 Ella Baila Sola
# 2   1nrVofqDRs7cpWXJ49qTnP                                             SOS
# 3   4kS7bSuU0Jm9LYMosFU2x5                              MAÑANA SERÁ BONITO
# 4   6aBVGuOUEuX18rHxyDWbti                                 La Bebe (Remix)
# 5   50uChhk7AKkzDKytDixjYW                                              RR
# 6   67WUCOjyl44d8fAFzHONjW                                 Search & Rescue
# 7   5letLUZIFsQikJYShfGNs4                            The Beginning: Cupid
# 8   5r36AJ6VOJtp00oxSkBZ5h                                   Harry's House
# 9   6cVfHBcp3AdpYY0bBglkLN                              Boy's a liar Pt. 2
# 10  35dut3ICqF3NEDkjxfzJJ1                                Starboy (Deluxe)
# ...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   album_id            50 non-null     object
#  1   album_name          50 non-null     object
#  2   album_release_date  50 non-null     object
#  3   album_total_tracks  50 non-null     int64
#  4   album_url           50 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.1+ KB

# %%
album_df=album_df.drop_duplicates(subset=['album_id'])

# %%
album_df
# Out:
#                   album_id                                      album_name  \
# 0   0HiZ8fNXwJOQcrf5iflrdz                         Endless Summer Vacation
# 1   3Mm1P5CEEAiuJqBclr2EyU                                 Ella Baila Sola
# 2   1nrVofqDRs7cpWXJ49qTnP                                             SOS
# 3   4kS7bSuU0Jm9LYMosFU2x5                              MAÑANA SERÁ BONITO
# 4   6aBVGuOUEuX18rHxyDWbti                                 La Bebe (Remix)
# 5   50uChhk7AKkzDKytDixjYW                                              RR
# 6   67WUCOjyl44d8fAFzHONjW                                 Search & Rescue
# 7   5letLUZIFsQikJYShfGNs4                            The Beginning: Cupid
# 8   5r36AJ6VOJtp00oxSkBZ5h                                   Harry's House
# 9   6cVfHBcp3AdpYY0bBglkLN                              Boy's a liar Pt. 2
# 10  35dut3ICqF3NEDkjxfzJJ1                                Starboy (Deluxe)
# ...

# %%
artist_df=pd.DataFrame.from_dict(artist_list)

# %%
artist_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   artist_id     77 non-null     object
#  1   artist_name   77 non-null     object
#  2   external_url  77 non-null     object
# dtypes: object(3)
# memory usage: 1.9+ KB

# %%
artist_df=artist_df.drop_duplicates(subset=['artist_id'])

# %%
artist_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 61 entries, 0 to 76
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   artist_id     61 non-null     object
#  1   artist_name   61 non-null     object
#  2   external_url  61 non-null     object
# dtypes: object(3)
# memory usage: 1.9+ KB

# %%
song_df=pd.DataFrame.from_dict(song_list).drop_duplicates(subset=['song_id'])

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      50 non-null     object
#  1   song_name    50 non-null     object
#  2   duration_ms  50 non-null     int64
#  3   url          50 non-null     object
#  4   popularity   50 non-null     int64
#  5   song_added   50 non-null     object
#  6   album_id     50 non-null     object
#  7   artist_id    50 non-null     object
# dtypes: int64(2), object(6)
# memory usage: 3.5+ KB

# %%
song_df.head()
# Out:
#                   song_id        song_name  duration_ms  \
# 0  4DHcnVTT87F0zZhRPYmZ3B          Flowers       200600
# 1  3dnP0JxCgygwQH9Gm7q7nb  Ella Baila Sola       165671
# 2  1Qrg8KqiBpW07V7PNxwwwL        Kill Bill       153946
# 3  0DWdj2oZMBFSzRsi2Cvfzf              TQG       197933
# 4  2UW7JaomAMuX9pZrjVpHAU  La Bebe - Remix       234352
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/4DHcnVTT87F0zZh...          91
# 1  https://open.spotify.com/track/3dnP0JxCgygwQH9...          97
# 2  https://open.spotify.com/track/1Qrg8KqiBpW07V7...          95
# 3  https://open.spotify.com/track/0DWdj2oZMBFSzRs...          98
# 4  https://open.spotify.com/track/2UW7JaomAMuX9pZ...          95
#
#              song_added                album_id               artist_id
# 0  2023-04-14T09:53:58Z  0HiZ8fNXwJOQcrf5iflrdz  5YGY8feqx7naU7z4HrwZM6
# 1  2023-04-14T09:53:58Z  3Mm1P5CEEAiuJqBclr2EyU  0XeEobZplHxzM9QzFQWLiR
# ...

# %%
artist_df.head()
# Out:
#                 artist_id     artist_name  \
# 0  5YGY8feqx7naU7z4HrwZM6     Miley Cyrus
# 1  0XeEobZplHxzM9QzFQWLiR  Eslabon Armado
# 2  12GqGscKJx3aE4t07u7eVZ      Peso Pluma
# 3  7tYKF4w9nC0nq9CsPZTHyP             SZA
# 4  790FomKkXshlbRYZFtlgla         KAROL G
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/5YGY8feqx7n...
# 1  https://api.spotify.com/v1/artists/0XeEobZplHx...
# 2  https://api.spotify.com/v1/artists/12GqGscKJx3...
# 3  https://api.spotify.com/v1/artists/7tYKF4w9nC0...
# 4  https://api.spotify.com/v1/artists/790FomKkXsh...

# %%
album_df.head()
# Out:
#                  album_id               album_name album_release_date  \
# 0  0HiZ8fNXwJOQcrf5iflrdz  Endless Summer Vacation         2023-03-10
# 1  3Mm1P5CEEAiuJqBclr2EyU          Ella Baila Sola         2023-03-16
# 2  1nrVofqDRs7cpWXJ49qTnP                      SOS         2022-12-08
# 3  4kS7bSuU0Jm9LYMosFU2x5       MAÑANA SERÁ BONITO         2023-02-24
# 4  6aBVGuOUEuX18rHxyDWbti          La Bebe (Remix)         2023-03-17
#
#    album_total_tracks                                          album_url
# 0                  13  https://open.spotify.com/album/0HiZ8fNXwJOQcrf...
# 1                   1  https://open.spotify.com/album/3Mm1P5CEEAiuJqB...
# 2                  23  https://open.spotify.com/album/1nrVofqDRs7cpWX...
# 3                  17  https://open.spotify.com/album/4kS7bSuU0Jm9LYM...
# 4                   2  https://open.spotify.com/album/6aBVGuOUEuX18rH...

# %% [markdown]
# ## Transformation

# %%
album_df['album_release_date']=pd.to_datetime(album_df['album_release_date'])
# Out:
# /var/folders/6c/691hvyfs46z4yzc6n5w0q_t80000gn/T/ipykernel_73954/2550147589.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   album_df['album_release_date']=pd.to_datetime(album_df['album_release_date'])

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   album_id            49 non-null     object
#  1   album_name          49 non-null     object
#  2   album_release_date  49 non-null     datetime64[ns]
#  3   album_total_tracks  49 non-null     int64
#  4   album_url           49 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 2.3+ KB

# %%
song_df.head()
# Out:
#                   song_id        song_name  duration_ms  \
# 0  4DHcnVTT87F0zZhRPYmZ3B          Flowers       200600
# 1  3dnP0JxCgygwQH9Gm7q7nb  Ella Baila Sola       165671
# 2  1Qrg8KqiBpW07V7PNxwwwL        Kill Bill       153946
# 3  0DWdj2oZMBFSzRsi2Cvfzf              TQG       197933
# 4  2UW7JaomAMuX9pZrjVpHAU  La Bebe - Remix       234352
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/4DHcnVTT87F0zZh...          91
# 1  https://open.spotify.com/track/3dnP0JxCgygwQH9...          97
# 2  https://open.spotify.com/track/1Qrg8KqiBpW07V7...          95
# 3  https://open.spotify.com/track/0DWdj2oZMBFSzRs...          98
# 4  https://open.spotify.com/track/2UW7JaomAMuX9pZ...          95
#
#              song_added                album_id               artist_id
# 0  2023-04-14T09:53:58Z  0HiZ8fNXwJOQcrf5iflrdz  5YGY8feqx7naU7z4HrwZM6
# 1  2023-04-14T09:53:58Z  3Mm1P5CEEAiuJqBclr2EyU  0XeEobZplHxzM9QzFQWLiR
# ...

# %%
song_df['song_added']=pd.to_datetime(song_df['song_added'])

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      50 non-null     object
#  1   song_name    50 non-null     object
#  2   duration_ms  50 non-null     int64
#  3   url          50 non-null     object
#  4   popularity   50 non-null     int64
#  5   song_added   50 non-null     datetime64[ns, UTC]
#  6   album_id     50 non-null     object
#  7   artist_id    50 non-null     object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 3.5+ KB
